# %%
# %cd -q /home/mdean/SIX_plotter/

# %%
from IPython.display import display

import plotter_components
from importlib import reload
reload(plotter_components)
from plotter_components import *

# %matplotlib notebook

# %%
display(widgets.HBox([db_search_widget, refresh_headers_widget]))
display(select_scan_id_widget)
# Out:
# HBox(children=(Text(value="since='2018-06-03'", description='Database search'), Button(description='Refresh', …
# Select(description='Select scan id', options=(), value=None)

# %%
plt.figure()
plt.plot(1,1)
display(widgets.HBox([select_x_widget, select_y_widget, use_mon_widget, select_mon_widget]))
display(widgets.HBox([plot_button, clear_button]) )
# Out:
# <img src="data:image/png;base64,..." width="640">
# HBox(children=(Dropdown(description='x', options=(), value=None), Dropdown(description='y', options=(), value=…
# HBox(children=(Button(description='Plot', style=ButtonStyle()), Button(description='Clear', style=ButtonStyle(…

# %%
display(widgets.VBox([baseline_button, baseline_display]))
# Out:
# VBox(children=(Button(description='Display baseline', style=ButtonStyle()), HTML(value='Baseline')))

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {

 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to show/hide code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to show/hide code."></form>
